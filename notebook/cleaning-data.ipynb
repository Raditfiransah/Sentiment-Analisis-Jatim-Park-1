# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Jatim-Park-1-500-Labeled.csv')

# %%
df
# Out:
#      annotation_id  annotator                   created_at   id  lead_time  \
# 0                6          1  2025-11-07T13:13:41.663999Z    1     19.562
# 1              503          1  2025-11-09T11:38:38.849114Z    2     14.749
# 2              504          1  2025-11-09T11:38:50.890259Z    3     10.339
# 3              505          1  2025-11-09T11:39:17.541252Z    4     17.949
# 4                7          1  2025-11-07T13:13:52.121104Z    5     10.015
# ..             ...        ...                          ...  ...        ...
# 495            496          1  2025-11-08T13:21:26.526122Z  496      2.213
# 496            497          1  2025-11-08T13:21:31.902866Z  497      4.880
# 497            498          1  2025-11-08T13:21:36.089968Z  498      3.680
# 498            499          1  2025-11-08T13:21:38.791192Z  499      2.257
# 499            500          1  2025-11-08T13:21:43.871183Z  500      4.505
#
# ...

# %%
df.isnull().sum()
# Out:
# annotation_id    0
# annotator        0
# created_at       0
# id               0
# lead_time        0
# rating           0
# review           0
# sentiment        0
# updated_at       0
# user             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_final = df[['user', 'review', 'rating', 'sentiment']]

# %%
df_final
# Out:
#                     user                                             review  \
# 0              Cristanto  Tempat wisata di batu bisa buat keluarga atau ...
# 1           Erma Latifah  Masih lumayan buat anak2 wisata...edukasi dan ...
# 2        Nailil Farikhah  Adalah sebuah tempat untuk edukasi, rekreasi, ...
# 3        Theresia Lonika  Bagus utk wisata utk edukasi dan taman bermain...
# 4            zainal arif  Tiket masuk dibandingkan dengan banyaknya waha...
# ..                   ...                                                ...
# 495        Agung Setiono  Manajemen nya tidak ketat dalam penerapan prok...
# 496       wiwin harijani  Banyak mainannya luas sayang kmrn hujan, menga...
# 497      Harni Wulandari  Tempat rekreasi seruu.. tiap tahun ada aja yg ...
# 498  Lufena Fitra Krisma  Tempat wisata + rekreasi yang menyenangkan coc...
# 499         Ilfa Rosidah  Tempat wisata di kota batu malang yang sangat ...
#
#      rating sentiment
# 0         5   Neutral
# ...

# %%
df_final.to_csv('../data/Jatim-park-1-500-Labeled-clean.csv', index=False)
